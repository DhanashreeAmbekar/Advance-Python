# %% [markdown]
# ### Uber Data Analysis Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\DELL\\Desktop\\Excel_Data\\UberDataset.csv")

# %%
df.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.isna().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
df["PURPOSE"].fillna('NOT',inplace=True)

# %%
df.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df["START_DATE"]=pd.to_datetime(df["START_DATE"],errors="coerce")

# %%
df["END_DATE"]=pd.to_datetime(df["END_DATE"],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

# %%
df["date"]=pd.DatetimeIndex(df["START_DATE"]).date

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01
# 1      Fort Pierce    5.0              NOT  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06

# %%
df["time"]=pd.DatetimeIndex(df["START_DATE"]).hour

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
df["day_night"]=pd.cut(x=df["time"],bins=[0,10,15,19,24],labels=["Morning","Afternoon","Evening","Night"])

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (413, 10)

# %% [markdown]
# ### Data Visualisation

# %% [markdown]
# ### which category travel most?

# %%
df["CATEGORY"].value_counts()
# Out:
# CATEGORY
# Business    400
# Personal     13
# Name: count, dtype: int64

# %%
sns.catplot(y="CATEGORY",data=df,kind="count",order=df["CATEGORY"].value_counts().index)
plt.title("Category")
plt.show()

# %% [markdown]
# ### What is most Purpose of using Uber?

# %%
sns.catplot(y="CATEGORY",data=df,kind="count",order=df["CATEGORY"].value_counts().index)
plt.title("Category")
plt.show()

# %%
sns.catplot(y="PURPOSE",data=df,kind="count",order=df["PURPOSE"].value_counts().index)
plt.title("Purpose")
plt.show()

# %% [markdown]
# ### At what time booking is max?

# %%
df["day_night"].value_counts()
# Out:
# day_night
# Afternoon    142
# Evening      137
# Night         71
# Morning       63
# Name: count, dtype: int64

# %%
sns.histplot(df["day_night"],kde=False)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### In which month do people book uber rides less frequent?

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
df["Month"]=pd.DatetimeIndex(df["START_DATE"]).month

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night  Mon  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night    1
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning    1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night    1
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening    1
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon    1
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df["Month"]=pd.DatetimeIndex(df["START_DATE"]).month

month_label={1.0:'jan', 2.0:'feb' ,3.0:'mar', 4.0:'apl',
             5.0:'may', 6.0:'jun' ,7.0:'jul' ,8.0:'aug',
             9.0:'sep' ,10.0:'oct' ,11.0:'nov' ,12.0:"dec"}
df["Month"]=df["Month"].map(month_label)
mon=df.Month.value_counts(sort=False)

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night  Mon  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night    1
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning    1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night    1
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening    1
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon    1
#
#   Month
# 0   jan
# 1   jan
# 2   jan
# 3   jan
# 4   jan

# %%
df["Month"].value_counts()
# Out:
# Month
# nov    63
# aug    43
# mar    42
# jun    42
# feb    40
# dec    39
# jul    34
# may    26
# apl    24
# oct    24
# jan    23
# sep    13
# Name: count, dtype: int64

# %%
sns.catplot(y="Month",data=df,kind="count",order=df["Month"].value_counts().index)
plt.title("Month")
plt.show()

# %%
sns.barplot(x="Month",y="MILES",data=df)
plt.show()

# %% [markdown]
# ### On which day of week do people book uber rides the most ?

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night  Mon  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night    1
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning    1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night    1
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening    1
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon    1
#
#   Month
# 0   jan
# 1   jan
# 2   jan
# 3   jan
# 4   jan

# %%
df["DAY"]=(df["START_DATE"]).dt.weekday

data_label={0:'Mon' ,1:'Tue' ,3:'Wed',
            4:'Thur', 5:'Fri' , 6:'Sat' ,
            7:'Sun'}

df["DAY"]=df['DAY'].map(data_label)

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night  Mon  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night    1
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning    1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night    1
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening    1
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon    1
#
#   Month  WEEK   DAY
# 0   jan     4  Thur
# 1   jan     5   Fri
# 2   jan     5   Fri
# 3   jan     1   Tue
# ...

# %%
df["DAY"].value_counts()
# Out:
# DAY
# Thur    86
# Wed     61
# Mon     61
# Tue     58
# Fri     52
# Sat     47
# Name: count, dtype: int64

# %%
sns.histplot(df['DAY'],kde=False)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### For how many miles people usually book cab ?

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day_night  Mon  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night    1
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning    1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night    1
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening    1
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon    1
#
#   Month  WEEK   DAY
# 0   jan     4  Thur
# 1   jan     5   Fri
# 2   jan     5   Fri
# 3   jan     1   Tue
# ...

# %%
sns.boxplot(df["MILES"])
plt.show()

# %%
sns.boxplot(df[df["MILES"]<100]["MILES"])
# Out:
# <Axes: >

# %%
sns.distplot(df[df["MILES"]<40]['MILES'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_848\106657584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["MILES"]<40]['MILES'])
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
